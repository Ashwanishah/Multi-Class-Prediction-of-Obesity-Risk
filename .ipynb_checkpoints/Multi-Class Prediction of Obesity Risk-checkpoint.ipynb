# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv("Dataset/train.csv")
test=pd.read_csv("Dataset/test.csv")
submit=pd.read_csv("Dataset/sample_submission.csv")

# %%
train.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II

# %%
test.head()
# Out:
#       id  Gender        Age    Height      Weight  \
# 0  20758    Male  26.899886  1.848294  120.644178
# 1  20759  Female  21.000000  1.600000   66.000000
# 2  20760  Female  26.000000  1.643355  111.600553
# 3  20761    Male  20.979254  1.553127  103.669116
# 4  20762  Female  26.000000  1.627396  104.835346
#
#   family_history_with_overweight FAVC      FCVC       NCP       CAEC SMOKE  \
# 0                            yes  yes  2.938616  3.000000  Sometimes    no
# 1                            yes  yes  2.000000  1.000000  Sometimes    no
# 2                            yes  yes  3.000000  3.000000  Sometimes    no
# 3                            yes  yes  2.000000  2.977909  Sometimes    no
# 4                            yes  yes  3.000000  3.000000  Sometimes    no
#
#        CH2O SCC       FAF       TUE       CALC                 MTRANS
# 0  2.825629  no  0.855400  0.000000  Sometimes  Public_Transportation
# 1  3.000000  no  1.000000  0.000000  Sometimes  Public_Transportation
# 2  2.621877  no  0.000000  0.250502  Sometimes  Public_Transportation
# 3  2.786417  no  0.094851  0.000000  Sometimes  Public_Transportation
# 4  2.653531  no  0.000000  0.741069  Sometimes  Public_Transportation

# %%
train.NObeyesdad.nunique()
# Out:
# 7

# %%
train.NObeyesdad.unique()
# Out:
# array(['Overweight_Level_II', 'Normal_Weight', 'Insufficient_Weight',
#        'Obesity_Type_III', 'Obesity_Type_II', 'Overweight_Level_I',
#        'Obesity_Type_I'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
train["NObeyesdad_Encoder"]=encoder.fit_transform(train["NObeyesdad"])
train.head()
# Out:
#    id  Gender        Age    Height      Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998   81.669950                            yes
# 1   1  Female  18.000000  1.560000   57.000000                            yes
# 2   2  Female  18.000000  1.711460   50.165754                            yes
# 3   3  Female  20.952737  1.710730  131.274851                            yes
# 4   4    Male  31.641081  1.914186   93.798055                            yes
#
#   FAVC      FCVC       NCP        CAEC SMOKE      CH2O SCC       FAF  \
# 0  yes  2.000000  2.983297   Sometimes    no  2.763573  no  0.000000
# 1  yes  2.000000  3.000000  Frequently    no  2.000000  no  1.000000
# 2  yes  1.880534  1.411685   Sometimes    no  1.910378  no  0.866045
# 3  yes  3.000000  3.000000   Sometimes    no  1.674061  no  1.467863
# 4  yes  2.679664  1.971472   Sometimes    no  1.979848  no  1.967973
#
#         TUE       CALC                 MTRANS           NObeyesdad  \
# 0  0.976473  Sometimes  Public_Transportation  Overweight_Level_II
# 1  1.000000         no             Automobile        Normal_Weight
# 2  1.673584         no  Public_Transportation  Insufficient_Weight
# 3  0.780199  Sometimes  Public_Transportation     Obesity_Type_III
# 4  0.931721  Sometimes  Public_Transportation  Overweight_Level_II
#
#    NObeyesdad_Encoder
# 0                   6
# 1                   1
# 2                   0
# 3                   4
# 4                   6

# %%
train.groupby("NObeyesdad_Encoder")["SMOKE"].count()
# Out:
# NObeyesdad_Encoder
# 0    2523
# 1    3082
# 2    2910
# 3    3248
# 4    4046
# 5    2427
# 6    2522
# Name: SMOKE, dtype: int64

# %%
train["CALC"].unique()
# Out:
# array(['Sometimes', 'no', 'Frequently'], dtype=object)

# %%
sns.countplot(x="CALC",data=train)
plt.grid(alpha=0.3)

# %%
sns.countplot(x="NObeyesdad_Encoder",data=train)
plt.grid(alpha=0.3)

# %%
train.groupby("NObeyesdad_Encoder")["CALC"].count()
# Out:
# NObeyesdad_Encoder
# 0    2523
# 1    3082
# 2    2910
# 3    3248
# 4    4046
# 5    2427
# 6    2522
# Name: CALC, dtype: int64

# %%
train.groupby("Age")["NObeyesdad_Encoder"].count().to_frame()
# Out:
#            NObeyesdad_Encoder
# Age
# 14.000000                   5
# 15.000000                   3
# 16.000000                 109
# 16.093234                   4
# 16.120699                   1
# ...                       ...
# 55.246250                   2
# 55.272573                   1
# 55.493687                   1
# 56.000000                   1
# 61.000000                   2
#
# [1703 rows x 1 columns]

# %%
category_order=['Overweight_Level_II', 'Normal_Weight', 'Insufficient_Weight','Obesity_Type_III', 'Obesity_Type_II', 'Overweight_Level_I',
       'Obesity_Type_I']

# %%
sns.countplot(x="Gender",hue="NObeyesdad_Encoder",data=train)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.scatterplot(x='Height', y='Weight', hue='NObeyesdad', data=train)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.violinplot(data=train, x='Age', y='Gender', hue='SMOKE')
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
sns.countplot(x=train["family_history_with_overweight"],hue="NObeyesdad",data=train,hue_order=category_order)
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='count'>

# %%
train.isnull().sum()
# Out:
# id                                0
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# NObeyesdad_Encoder                0
# dtype: int64

# %%
train.head(2)
# Out:
#    id  Gender        Age    Height    Weight family_history_with_overweight  \
# 0   0    Male  24.443011  1.699998  81.66995                            yes
# 1   1  Female  18.000000  1.560000  57.00000                            yes
#
#   FAVC  FCVC       NCP        CAEC SMOKE      CH2O SCC  FAF       TUE  \
# 0  yes   2.0  2.983297   Sometimes    no  2.763573  no  0.0  0.976473
# 1  yes   2.0  3.000000  Frequently    no  2.000000  no  1.0  1.000000
#
#         CALC                 MTRANS           NObeyesdad  NObeyesdad_Encoder
# 0  Sometimes  Public_Transportation  Overweight_Level_II                   6
# 1         no             Automobile        Normal_Weight                   1

# %% [markdown]
# ## AGE GROUP HIGHLY AFFECTED BY NOBEYESDAD

# %%
train.Age.nunique()
# Out:
# 1703

# %%
plt.figure(figsize=(12,4))
sns.histplot(data=train,x="Age",bins=30,hue="NObeyesdad",hue_order=category_order,kde=True)
plt.xticks(np.arange(0, 80, step=5))
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.stripplot(data=train,x='Age',y=train["NObeyesdad"])
plt.xticks(np.arange(0, 65, step=5))
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.violinplot(data=train, x='Age', y=train["NObeyesdad"])
plt.grid(alpha=0.3)

# %% [markdown]
# ## MOST COMMON TYPE OF NOBEYESDAD

# %%
plt.figure(figsize=(12,8))
ax=sns.countplot(x="NObeyesdad",data=train)
for i in ax.containers:
    ax.bar_label(i,)
plt.grid(alpha=0.3)

# %% [markdown]
# ## GENDER MOSTLY AFFECTED BY THIS NOBEYESDAD

# %% [markdown]
# ### Which is most affected ?

# %%
train.groupby("Gender")["Age"].count()
# Out:
# Gender
# Female    10422
# Male      10336
# Name: Age, dtype: int64

# %%
train.groupby("Gender")["NObeyesdad"].value_counts().to_frame()
# Out:
#                             count
# Gender NObeyesdad
# Female Obesity_Type_III      4041
#        Normal_Weight         1660
#        Insufficient_Weight   1621
#        Obesity_Type_I        1267
#        Overweight_Level_I    1070
#        Overweight_Level_II    755
#        Obesity_Type_II          8
# Male   Obesity_Type_II       3240
#        Overweight_Level_II   1767
#        Obesity_Type_I        1643
#        Normal_Weight         1422
#        Overweight_Level_I    1357
#        Insufficient_Weight    902
#        Obesity_Type_III         5

# %%
plt.figure(figsize=(12,8))
ax=sns.countplot(x="Gender",hue="NObeyesdad",data=train,hue_order=category_order)
for i in ax.containers:
    ax.bar_label(i,)

# %%
plt.figure(figsize=(10,12))
sns.violinplot(data=train, x='Age', hue='Gender', y=train["NObeyesdad"])
plt.grid(alpha=0.3)

# %% [markdown]
# ## FAMILY HISTORY WITH OVERWT.

# %%
train.groupby("family_history_with_overweight")["Age"].count()
# Out:
# family_history_with_overweight
# no      3744
# yes    17014
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.histplot(data=train,x='Age', hue=train["family_history_with_overweight"],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(14,6))
sns.violinplot(data=train, x='Age', hue='Gender', y=train["family_history_with_overweight"])
plt.grid(alpha=0.3)

# %%
train.groupby("SMOKE")["NObeyesdad"].value_counts().to_frame()
# Out:
#                            count
# SMOKE NObeyesdad
# no    Obesity_Type_III      4042
#       Obesity_Type_II       3134
#       Normal_Weight         3036
#       Obesity_Type_I        2886
#       Insufficient_Weight   2516
#       Overweight_Level_II   2497
#       Overweight_Level_I    2402
# yes   Obesity_Type_II        114
#       Normal_Weight           46
#       Overweight_Level_I      25
#       Overweight_Level_II     25
#       Obesity_Type_I          24
#       Insufficient_Weight      7
#       Obesity_Type_III         4

# %%
plt.figure(figsize=(12,12))
sns.histplot(data=train,x="Age",hue="SMOKE",kde=True)
plt.yticks(np.arange(0,3000,10))
plt.show()

# %%
plt.figure(figsize=(12,8))
ax=sns.countplot(x="SMOKE",hue="NObeyesdad",data=train,hue_order=category_order)
for i in ax.containers:
    ax.bar_label(i,)

# %%
train["MTRANS"].unique()
# Out:
# array(['Public_Transportation', 'Automobile', 'Walking', 'Motorbike',
#        'Bike'], dtype=object)

# %%
xm=train.groupby("MTRANS")["NObeyesdad"].count()
xm.sort_values(ascending=False)
# Out:
# MTRANS
# Public_Transportation    16687
# Automobile                3534
# Walking                    467
# Motorbike                   38
# Bike                        32
# Name: NObeyesdad, dtype: int64

# %%
plt.figure(figsize=(12,4))
ax=sns.countplot(data=train,x="MTRANS",hue="Gender")
for i in ax.containers:
    ax.bar_label(i,)

# %%
plt.figure(figsize=(12,5))
sns.violinplot(data=train,x="MTRANS",y="Age",orient="v")
plt.grid(alpha=0.3)

# %% [markdown]
# ## CO-RELATION

# %%
train.corr(numeric_only=True).style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_d4ab3_row0_col0, #T_d4ab3_row1_col1, #T_d4ab3_row2_col2, #T_d4ab3_row3_col3, #T_d4ab3_row4_col4, #T_d4ab3_row5_col5, #T_d4ab3_row6_col6, #T_d4ab3_row7_col7, #T_d4ab3_row8_col8, #T_d4ab3_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col1, #T_d4ab3_row0_col8, #T_d4ab3_row6_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_d4ab3_row0_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col3, #T_d4ab3_row3_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col5, #T_d4ab3_row4_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d4ab3_row0_col9, #T_d4ab3_row7_col6 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d4ab3_row1_col0, #T_d4ab3_row6_col0, #T_d4ab3_row8_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d4ab3_row1_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d4ab3_row1_col3, #T_d4ab3_row3_col4, #T_d4ab3_row7_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_d4ab3_row1_col4, #T_d4ab3_row6_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d4ab3_row1_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d4ab3_row1_col6, #T_d4ab3_row1_col7, #T_d4ab3_row1_col8, #T_d4ab3_row4_col0, #T_d4ab3_row4_col2, #T_d4ab3_row5_col0, #T_d4ab3_row7_col3, #T_d4ab3_row7_col9, #T_d4ab3_row8_col1, #T_d4ab3_row8_col3, #T_d4ab3_row8_col4, #T_d4ab3_row9_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d4ab3_row1_col9 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_d4ab3_row2_col0, #T_d4ab3_row3_col0, #T_d4ab3_row9_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d4ab3_row2_col1, #T_d4ab3_row6_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_d4ab3_row2_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d4ab3_row2_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_d4ab3_row2_col5, #T_d4ab3_row6_col9 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_d4ab3_row2_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_d4ab3_row2_col7 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_d4ab3_row2_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d4ab3_row2_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d4ab3_row3_col1, #T_d4ab3_row9_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_d4ab3_row3_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d4ab3_row3_col5, #T_d4ab3_row9_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d4ab3_row3_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_d4ab3_row3_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_d4ab3_row3_col9 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_d4ab3_row4_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_d4ab3_row4_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_d4ab3_row4_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_d4ab3_row4_col6, #T_d4ab3_row4_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_d4ab3_row4_col9 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d4ab3_row5_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_d4ab3_row5_col2, #T_d4ab3_row5_col7, #T_d4ab3_row7_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d4ab3_row5_col3, #T_d4ab3_row9_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d4ab3_row5_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_d4ab3_row5_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d4ab3_row5_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d4ab3_row5_col9, #T_d4ab3_row8_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d4ab3_row6_col1, #T_d4ab3_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d4ab3_row6_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_d4ab3_row6_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_d4ab3_row7_col0, #T_d4ab3_row8_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d4ab3_row7_col1, #T_d4ab3_row9_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d4ab3_row7_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d4ab3_row7_col5, #T_d4ab3_row8_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_d4ab3_row8_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d4ab3_row8_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_d4ab3_row9_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_d4ab3_row9_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_d4ab3_row9_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d4ab3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4ab3_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_d4ab3_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_d4ab3_level0_col2" class="col_heading level0 col2" >Height</th>
#       <th id="T_d4ab3_level0_col3" class="col_heading level0 col3" >Weight</th>
#       <th id="T_d4ab3_level0_col4" class="col_heading level0 col4" >FCVC</th>
#       <th id="T_d4ab3_level0_col5" class="col_heading level0 col5" >NCP</th>
#       <th id="T_d4ab3_level0_col6" class="col_heading level0 col6" >CH2O</th>
#       <th id="T_d4ab3_level0_col7" class="col_heading level0 col7" >FAF</th>
#       <th id="T_d4ab3_level0_col8" class="col_heading level0 col8" >TUE</th>
#       <th id="T_d4ab3_level0_col9" class="col_heading level0 col9" >NObeyesdad_Encoder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4ab3_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_d4ab3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d4ab3_row0_col1" class="data row0 col1" >0.007634</td>
#       <td id="T_d4ab3_row0_col2" class="data row0 col2" >0.012041</td>
#       <td id="T_d4ab3_row0_col3" class="data row0 col3" >0.014020</td>
#       <td id="T_d4ab3_row0_col4" class="data row0 col4" >0.002098</td>
#       <td id="T_d4ab3_row0_col5" class="data row0 col5" >-0.000332</td>
#       <td id="T_d4ab3_row0_col6" class="data row0 col6" >0.007917</td>
#       <td id="T_d4ab3_row0_col7" class="data row0 col7" >0.016719</td>
#       <td id="T_d4ab3_row0_col8" class="data row0 col8" >0.007667</td>
#       <td id="T_d4ab3_row0_col9" class="data row0 col9" >0.012329</td>
#     </tr>
#     <tr>
#       <th id="T_d4ab3_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_d4ab3_row1_col0" class="data row1 col0" >0.007634</td>
#       <td id="T_d4ab3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d4ab3_row1_col2" class="data row1 col2" >-0.011713</td>
#       <td id="T_d4ab3_row1_col3" class="data row1 col3" >0.283381</td>
#       <td id="T_d4ab3_row1_col4" class="data row1 col4" >0.034414</td>
#       <td id="T_d4ab3_row1_col5" class="data row1 col5" >-0.048479</td>
#       <td id="T_d4ab3_row1_col6" class="data row1 col6" >-0.016325</td>
#       <td id="T_d4ab3_row1_col7" class="data row1 col7" >-0.192259</td>
#       <td id="T_d4ab3_row1_col8" class="data row1 col8" >-0.296154</td>
#       <td id="T_d4ab3_row1_col9" class="data row1 col9" >0.283018</td>
#     </tr>
#     <tr>
#       <th id="T_d4ab3_level0_row2" class="row_heading level0 row2" >Height</th>
#       <td id="T_d4ab3_row2_col0" class="data row2 col0" >0.012041</td>
#       <td id="T_d4ab3_row2_col1" class="data row2 col1" >-0.011713</td>
#       <td id="T_d4ab3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d4ab3_row2_col3" class="data row2 col3" >0.416677</td>
#       <td id="T_d4ab3_row2_col4" class="data row2 col4" >-0.071546</td>
#       <td id="T_d4ab3_row2_col5" class="data row2 col5" >0.191383</td>
#       <td id="T_d4ab3_row2_col6" class="data row2 col6" >0.183706</td>
#       <td id="T_d4ab3_row2_col7" class="data row2 col7" >0.295278</td>
#       <td id="T_d4ab3_row2_col8" c

# %%
corr=train.corr(numeric_only=True)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True,cmap="mako",fmt='.2f')
# Out:
# <Axes: >

# %%
train.corrwith(train.NObeyesdad_Encoder,numeric_only=True).sort_values(ascending=False,key=(lambda x:abs(x)))
# Out:
# NObeyesdad_Encoder    1.000000
# Weight                0.431821
# Age                   0.283018
# CH2O                  0.187100
# FAF                  -0.096643
# NCP                  -0.091154
# TUE                  -0.076040
# Height                0.060786
# FCVC                  0.041076
# id                    0.012329
# dtype: float64

# %% [markdown]
# ## Pre_processing

# %%
from sklearn.model_selection import train_test_split

# %%
features=train.drop(["id","NObeyesdad_Encoder","NObeyesdad"],axis=1).copy()
labels=train["NObeyesdad"]

# %%
features.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS'],
#       dtype='object')

# %%
labels
# Out:
# 0        Overweight_Level_II
# 1              Normal_Weight
# 2        Insufficient_Weight
# 3           Obesity_Type_III
# 4        Overweight_Level_II
#                 ...
# 20753        Obesity_Type_II
# 20754    Insufficient_Weight
# 20755        Obesity_Type_II
# 20756    Overweight_Level_II
# 20757        Obesity_Type_II
# Name: NObeyesdad, Length: 20758, dtype: object

# %%
X_train,X_test,y_train,y_test=train_test_split(features,labels,random_state=42,test_size=0.2)

# %%
X_train.shape
# Out:
# (16606, 16)

# %%
X_test.shape
# Out:
# (4152, 16)

# %%
y_train.shape
# Out:
# (16606,)

# %%
y_test.shape
# Out:
# (4152,)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16606 entries, 9958 to 15795
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          16606 non-null  object
#  1   Age                             16606 non-null  float64
#  2   Height                          16606 non-null  float64
#  3   Weight                          16606 non-null  float64
#  4   family_history_with_overweight  16606 non-null  object
#  5   FAVC                            16606 non-null  object
#  6   FCVC                            16606 non-null  float64
#  7   NCP                             16606 non-null  float64
#  8   CAEC                            16606 non-null  object
#  9   SMOKE                           16606 non-null  object
#  10  CH2O                            16606 non-null  float64
#  11  SCC                             16606 non-null  object
#  12  FAF                             16606 non-null  float64
#  13  TUE                             16606 non-null  float64
#  14  CALC                            16606 non-null  object
#  15  MTRANS                          16606 non-null  object
# dtypes: float64(8), object(8)
# memory usage: 2.2+ MB

# %%
X_train.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS'],
#       dtype='object')

# %%
num_data=['Age', 'Height', 'Weight','FCVC', 'NCP','CH2O', 'FAF', 'TUE',]
cat_data=['Gender','family_history_with_overweight','FAVC', 'CAEC', 'SMOKE','SCC', 'CALC', 'MTRANS']

# %%
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.compose import ColumnTransformer,make_column_transformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler,FunctionTransformer,OrdinalEncoder
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, accuracy_score,roc_curve,roc_auc_score

# %%
pipe_num_val=make_pipeline(
    StandardScaler()
)
pipe_cat_val=make_pipeline(
    OneHotEncoder(handle_unknown='ignore')
)

# %%
inner=ColumnTransformer([
    ("Num_val",pipe_num_val,num_data),
    ("cat_val",pipe_cat_val,cat_data)
])

# %%
pipeline=Pipeline([
    ("Pipeline",inner),
    ("model",RandomForestClassifier())
])
pipeline
# Out:
# Pipeline(steps=[('Pipeline',
#                  ColumnTransformer(transformers=[('Num_val',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Height', 'Weight',
#                                                    'FCVC', 'NCP', 'CH2O', 'FAF',
#                                                    'TUE']),
#                                                  ('cat_val',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender',
#                                                    'family_history_with_overweight',
#                                                    'FAVC', 'CAEC', 'SMOKE',
#                                                    'SCC', 'CALC',
#                                                    'MTRANS'])])),
#                 ('model', RandomForestClassifier())])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Pipeline',
#                  ColumnTransformer(transformers=[('Num_val',
#                                                   Pipeline(steps=[('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Height', 'Weight',
#                                                    'FCVC', 'NCP', 'CH2O', 'FAF',
#                                                    'TUE']),
#                                                  ('cat_val',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Gender',
#                                                    'family_history_with_overweight',
#                                                    'FAVC', 'CAEC', 'SMOKE',
#                                                    'SCC', 'CALC',
#                                                    'MTRANS'])])),
#                 ('model', RandomForestClassifier())])

# %%
y_hat=pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_hat))
# Out:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.94      0.91      0.93       524
#       Normal_Weight       0.82      0.89      0.85       626
#      Obesity_Type_I       0.88      0.85      0.86       543
#     Obesity_Type_II       0.98      0.97      0.97       657
#    Obesity_Type_III       1.00      1.00      1.00       804
#  Overweight_Level_I       0.77      0.73      0.75       484
# Overweight_Level_II       0.76      0.78      0.77       514
#
#            accuracy                           0.89      4152
#           macro avg       0.88      0.88      0.88      4152
#        weighted avg       0.89      0.89      0.89      4152

# %% [markdown]
# ## Test data

# %%
new_df=test.copy()

# %%
temp=test["id"]

# %%
test=test.drop("id",axis=1)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13840 entries, 0 to 13839
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          13840 non-null  object
#  1   Age                             13840 non-null  float64
#  2   Height                          13840 non-null  float64
#  3   Weight                          13840 non-null  float64
#  4   family_history_with_overweight  13840 non-null  object
#  5   FAVC                            13840 non-null  object
#  6   FCVC                            13840 non-null  float64
#  7   NCP                             13840 non-null  float64
#  8   CAEC                            13840 non-null  object
#  9   SMOKE                           13840 non-null  object
#  10  CH2O                            13840 non-null  float64
#  11  SCC                             13840 non-null  object
#  12  FAF                             13840 non-null  float64
#  13  TUE                             13840 non-null  float64
#  14  CALC                            13840 non-null  object
#  15  MTRANS                          13840 non-null  object
# dtypes: float64(8), object(8)
# memory usage: 1.7+ MB

# %%
test.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# dtype: int64

# %% [markdown]
# ##### NO NULL VALUE PRESENT IN TESTS DATASET

# %%
test.duplicated().sum()
# Out:
# 0

# %%
y_hat=test_data=pipeline.predict(test)

# %%
y_hat
# Out:
# array(['Obesity_Type_II', 'Overweight_Level_I', 'Obesity_Type_III', ...,
#        'Insufficient_Weight', 'Normal_Weight', 'Obesity_Type_II'],
#       dtype=object)

# %%
df_test_pred = df_test[['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
       'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
       'CALC', 'MTRANS']]

# %%
# submitting file
rfc_prediction = pipeline.predict(test)

output = pd.DataFrame({'id': new_df.id, 'NObeyesdad':rfc_prediction})
output.to_csv('Multi-Class Prediction of Obesity Risk.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
